# %% [markdown]
# ## Citibike Usage Seasonal Dynamic

# %% [markdown]
# #### Introduction:
# Citibike data shows that there is a seasonality with bike ridership for subscribers. It says that there is relatively low bike usage during winter time.
#
# It is presumed that many subscribers follow a pattern in trip duration, such as grocery shopping or commuting. However, it is not clear that whether there is a seasonal dynamic in such usage pattern. In this research, we look into citibike data generated by subscribers in summer months (July and August, 2015) and winter months (January and Febuary, 2015), in order to compare the seasonal difference in trip duration generated by subscribers.

# %% [markdown]
# ### Hypothesis Development:
# #### H0 = μ1 - μ2 = 0
# We question if there is a significant difference between the mean of trip duration in summer months and winter months by subscribers. There is no difference in the average trip duration of subscribers in summer months as compared to the winter months.

# %% [markdown]
# #### H1= μ1 - μ2 != 0
#
# We will use a significance level  $\alpha=0.05$

# %%
from __future__ import print_function

# %pylab inline
import pandas as pd
import os
import sys
import numpy as np
from scipy.stats import norm
from scipy import stats
from scipy.optimize import curve_fit, minimize
from numpy import random
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
sns.set(context='notebook', style='whitegrid', palette='deep', font='sans-serif', font_scale=1, rc=None)
import pylab as pl
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
jul = pd.read_csv(os.getenv("PUIDATA")+"/201507-citibike-tripdata.csv")
aug = pd.read_csv(os.getenv("PUIDATA")+"/201508-citibike-tripdata.csv")
summer = pd.concat([jul, aug], axis = 0)

jan = pd.read_csv(os.getenv("PUIDATA")+"/201501-citibike-tripdata.csv")
feb = pd.read_csv(os.getenv("PUIDATA")+"/201502-citibike-tripdata.csv")
winter = pd.concat([jan, feb], axis = 0)

# %%
len(summer)
# Out:
# 2264720

# %%
len(winter)
# Out:
# 482482

# %%
# Subset a dataframe with subscribers only.
summer_sub = summer[summer['usertype'] == 'Subscriber']
winter_sub = winter[winter['usertype'] == 'Subscriber']

# %%
summer_sub.head()
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           732  7/1/2015 00:00:03  7/1/2015 00:12:16               489
# 1           322  7/1/2015 00:00:06  7/1/2015 00:05:29               304
# 2           790  7/1/2015 00:00:17  7/1/2015 00:13:28               447
# 3          1228  7/1/2015 00:00:23  7/1/2015 00:20:51               490
# 4          1383  7/1/2015 00:00:44  7/1/2015 00:23:48               327
#
#          start station name  start station latitude  start station longitude  \
# 0          10 Ave & W 28 St               40.750664               -74.001768
# 1     Broadway & Battery Pl               40.704633               -74.013617
# 2           8 Ave & W 52 St               40.763707               -73.985162
# 3           8 Ave & W 33 St               40.751551               -73.993934
# 4  Vesey Pl & River Terrace               40.715338               -74.016584
#
#    end station id               end station name  end station latitude  \
# 0             368             Carmine St & 6 Ave             40.730386
# 1            3002     South End Ave & Liberty St             40.711512
# 2             358  Christopher St & Greenwich St             40.732916
# 3             250       Lafayette St & Jersey St             40.724561
# 4              72               W 52 St & 11 Ave             40.767272
#
#    end station longitude  bikeid    usertype  birth year  gender
# 0             -74.002150   18669  Subscriber      1970.0       1
# 1             -74.015756   14618  Subscriber      1984.0       1
# 2             -74.007114   18801  Subscriber      1992.0       1
# 3             -73.995653   19137  Subscriber      1990.0       1
# 4             -73.993929   15808  Subscriber      1988.0       1

# %%
len(summer_sub)
# Out:
# 1863362

# %%
winter_sub.head(3)
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0          1346  1/1/2015 0:01  1/1/2015 0:24               455
# 1           363  1/1/2015 0:02  1/1/2015 0:08               434
# 2           346  1/1/2015 0:04  1/1/2015 0:10               491
#
#      start station name  start station latitude  start station longitude  \
# 0       1 Ave & E 44 St               40.750020               -73.969053
# 1       9 Ave & W 18 St               40.743174               -74.003664
# 2  E 24 St & Park Ave S               40.740964               -73.986022
#
#    end station id          end station name  end station latitude  \
# 0             265  Stanton St & Chrystie St             40.722293
# 1             482           W 15 St & 7 Ave             40.739355
# 2             505           6 Ave & W 33 St             40.749013
#
#    end station longitude  bikeid    usertype  birth year  gender
# 0             -73.991475   18660  Subscriber      1960.0       2
# 1             -73.999318   16085  Subscriber      1963.0       1
# 2             -73.988484   20845  Subscriber      1974.0       1

# %%
summer_mean = summer_sub['tripduration'].mean()
winter_mean = winter_sub['tripduration'].mean()

# %%
summer_sub['tripduration'].describe()
# Out:
# count    1.863362e+06
# mean     8.112439e+02
# std      5.576341e+03
# min      6.000000e+01
# 25%      3.820000e+02
# 50%      6.020000e+02
# 75%      9.600000e+02
# max      3.611666e+06
# Name: tripduration, dtype: float64

# %%
#We suspect there are outliers in our observations, therefore we need to clean
summer_dur = summer_sub['tripduration']
summer_dur_clean = summer_dur[(np.abs(stats.zscore(summer_dur)) < 3)]

winter_dur = winter_sub['tripduration']
winter_dur_clean = winter_dur[(np.abs(stats.zscore(winter_dur)) < 3)]

# %%
summer_dur_clean = summer_dur_clean.to_frame()

# %%
winter_dur_clean = winter_dur_clean.to_frame()

# %%
stats.ttest_ind(summer_dur_clean, winter_dur_clean, equal_var= False)
# Out:
# Ttest_indResult(statistic=array([ 203.14597566]), pvalue=array([ 0.]))

# %%
summer_dur_clean.describe()
# Out:
#        tripduration
# count  1.861956e+06
# mean   7.573256e+02
# std    6.167404e+02
# min    6.000000e+01
# 25%    3.820000e+02
# 50%    6.010000e+02
# 75%    9.590000e+02
# max    1.753000e+04

# %%
winter_dur_clean.describe()
# Out:
#         tripduration
# count  472979.000000
# mean      606.803974
# std       403.792930
# min        60.000000
# 25%       334.000000
# 50%       499.000000
# 75%       753.000000
# max      3179.000000

# %%
fig=pl.figure(figsize(15,15))
# Create trip duration bins, in this case we use 180 seconds (3 mins) as interval for the bins.
bins = np.arange(10, 3000, 100)

# Aggregates of trip duration:
ag_summer = summer_dur_clean.groupby(pd.cut(summer_dur_clean, bins)).agg([count_nonzero])
ag_winter = winter_dur_clean.groupby(pd.cut(winter_dur_clean, bins)).agg([count_nonzero])
ag_summer[:10]
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-35-5e80376093b5> in <module>()
#       4
#       5 # Aggregates of trip duration:
# ----> 6 ag_summer = summer_dur_clean.groupby(pd.cut(summer_dur_clean, bins)).agg([count_nonzero])
#       7 ag_winter = winter_dur_clean.groupby(pd.cut(winter_dur_clean, bins)).agg([count_nonzero])
#       8 ag_summer[:10]
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    3595     @Appender(SelectionMixin._agg_doc)
#    3596     def aggregate(self, arg, *args, **kwargs):
# -> 3597         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    3598
#    3599     agg = aggregate
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    3112
#    3113         _level = kwargs.pop('_level', None)
# -> 3114         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    3115         if how is None:
#    3116             return result
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/base.pyc in _aggregate(self, arg, *args, **kwargs)
#     562             return result, True
#     563         elif hasattr(arg, '__iter__'):
# --> 564             return self._aggregate_multiple_funcs(arg, _level=_level), None
#     565         else:
#     566             result = None
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/base.pyc in _aggregate_multiple_funcs(self, arg, _level)
#     607                 try:
#     608                     colg = self._gotitem(col, ndim=1, subset=obj[col])
# --> 609                     results.append(colg.aggregate(arg))
#     610                     keys.append(col)
#     611                 except (TypeError, DataError):
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/groupby.pyc in aggregate(self, func_or_funcs, *args, **kwargs)
#    2572         if hasattr(func_or_funcs, '__iter__'):
#    2573             ret = self._aggregate_multiple_funcs(func_or_funcs,
# -> 2574                                                  (_level or 0) + 1)
#    2575         else:
#    2576             cyfunc = self._is_cython_func(func_or_funcs)
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/groupby.pyc in _aggregate_multiple_funcs(self, arg, _level)
#    2634                 obj._reset_cache()
#    2635                 obj._selection = name
# -> 2636             results[name] = obj.aggregate(func)
#    2637
#    2638         if isinstance(list(compat.itervalues(results))[0],
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/groupby.pyc in aggregate(self, func_or_funcs, *args, **kwargs)
#    2584                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#    2585             except Exception:
# -> 2586                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#    2587
#    2588             index = Index(sorted(result), name=self.grouper.names[0])
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/groupby.pyc in _aggregate_named(self, func, *args, **kwargs)
#    2700         result = {}
#    2701
# -> 2702         for name, group in self:
#    2703             group.name = name
#    2704             output = func(group, *args, **kwargs)
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/groupby.pyc in get_iterator(self, data, axis)
#    1483         splitter = self._get_splitter(data, axis=axis)
#    1484         keys = self._get_group_keys()
# -> 1485         for key, (i, group) in zip(keys, splitter):
#    1486             yield key, group
#    1487
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/groupby.pyc in __iter__(self)
#    3879
#    3880     def __iter__(self):
# -> 3881         sdata = self._get_sorted_data()
#    3882
#    3883         if self.ngroups == 0:
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/groupby.pyc in _get_sorted_data(self)
#    3896
#    3897     def _get_sorted_data(self):
# -> 3898         return self.data.take(self.sort_idx, axis=self.axis, convert=False)
#    3899
#    3900     def _chop(self, sdata, slice_obj):
#
# pandas/src/properties.pyx in pandas.lib.cache_readonly.__get__ (pandas/lib.c:44097)()
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/groupby.pyc in sort_idx(self)
#    3876     def sort_idx(self):
#    3877         # Counting sort indexer
# -> 3878         return _get_group_index_sorter(self.labels, self.ngroups)
#    3879
#    3880     def __iter__(self):
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/core/groupby.pyc in _get_group_index_sorter(group_index, ngroups)
#    4261     if alpha + beta * ngroups < count * np.log(count):
#    4262         sorter, _ = _algos.groupsort_indexer(com._ensure_int64(group_index),
# -> 4263                                              ngroups)
#    4264         return com._ensure_platform_int(sorter)
#    4265     else:
#
# pandas/algos.pyx in pandas.algos.groupsort_indexer (pandas/algos.c:54509)()
#
# ValueError: Buffer has wrong number of dimensions (expected 1, got 2)
